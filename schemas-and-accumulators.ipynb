# %%
from pymongo import MongoClient
import pprint

# %%
course_cluster_uri = "mongodb://agg-student:agg-password@cluster0-shard-00-00-jxeqq.mongodb.net:27017,cluster0-shard-00-01-jxeqq.mongodb.net:27017,cluster0-shard-00-02-jxeqq.mongodb.net:27017/test?ssl=true&replicaSet=Cluster0-shard-0&authSource=admin"
course_client = MongoClient(course_cluster_uri)

# %%
orders = course_client['coursera-agg']['orders']

# %%
# Replace XXXX with a pipeline to add the fields mean_order_quantity, mean_order_unit_price,
# order_quantity, and order_total to each document. You can also add a $sort and $limit to your
# pipeline to answer the verification question.
pipeline = [
    {"$addFields":{
        "order_total":{"$reduce":{
                        "input":"$purchases",
                        "initialValue":0,
                        "in":{"$sum":[{"$multiply":["$$this.unit_price", "$$this.quantity"]},"$$value"]}
                        }
                      },
        "order_quantity":{"$sum":"$purchases.quantity"},
        "mean_order_unit_price":{"$avg":"$purchases.unit_price"},
        "mean_order_quantity":{"$avg":"$purchases.quantity"}
    }},
    {"$sort":{"order_total":-1}},
    {"$limit":5}
]

# %%
cursor = orders.aggregate(pipeline)

# %%
for doc in cursor:
    pprint.pprint(doc)
# Out:
# {'_id': 581483,
#  'country': 'United Kingdom',
#  'customer_id': 16446,
#  'date': datetime.datetime(2011, 12, 9, 9, 15),
#  'mean_order_quantity': 80995.0,
#  'mean_order_unit_price': 2.08,
#  'order_quantity': 80995,
#  'order_total': 168469.6,
#  'purchases': [{'description': 'PAPER CRAFT , LITTLE BIRDIE',
#                 'quantity': 80995,
#                 'stock_code': '23843',
#                 'unit_price': 2.08}]}
# {'_id': 541431,
#  'country': 'United Kingdom',
#  'customer_id': 12346,
#  'date': datetime.datetime(2011, 1, 18, 10, 1),
#  'mean_order_quantity': 74215.0,
#  'mean_order_unit_price': 1.04,
#  'order_quantity': 74215,
#  'order_total': 77183.6,
#  'purchases': [{'description': 'MEDIUM CERAMIC TOP STORAGE JAR',
#                 'quantity': 74215,
#                 'stock_code': '23166',
#                 'unit_price': 1.04}]}
# {'_id': 556444,
#  'country': 'United Kingdom',
#  'customer_id': 15098,
#  'date': datetime.datetime(2011, 6, 10, 15, 28),
#  'mean_order_quantity': 60.0,
#  'mean_order_unit_price': 649.5,
#  'order_quantity': 60,
#  'order_total': 38970.0,
#  'purchases': [{'description': 'PICNIC BASKET WICKER 60 PIECES',
#                 'quantity': 60,
#                 'stock_code': '22502',
#                 'unit_price': 649.5}]}
# {'_id': 567423,
#  'country': 'United Kingdom',
#  'customer_id': 17450,
#  'date': datetime.datetime(2011, 9, 20, 11, 5),
#  'mean_order_quantity': 1047.6666666666667,
#  'mean_order_unit_price': 3.0641666666666665,
#  'order_quantity': 12572,
#  'order_total': 31698.159999999996,
#  'purchases': [{'description': 'RECIPE BOX PANTRY YELLOW DESIGN',
#                 'quantity': 124,
#                 'stock_code': '22666',
#                 'unit_price': 3.2},
#                {'description': 'BLUE VINTAGE SPOT BEAKER',
#                 'quantity': 1878,
#                 'stock_code': '23286',
#                 'unit_price': 1.08},
#                {'description': 'METAL SIGN HER DINNER IS SERVED',
#                 'quantity': 248,
#                 'stock_code': '22117',
#                 'unit_price': 3.2},
#                {'description': 'PINK VINTAGE SPOT BEAKER',
#                 'quantity': 1944,
#                 'stock_code': '23285',
#                 'unit_price': 1.08},
#                {'description': 'GREEN VINTAGE SPOT BEAKER',
#                 'quantity': 1944,
#                 'stock_code': '23288',
#                 'unit_price': 1.08},
#                {'description': 'PANTRY CHOPPING BOARD',
#                 'quantity': 756,
#                 'stock_code': '23113',
#                 'unit_price': 5.06},
#                {'description': 'PANTRY WASHING UP BRUSH',
#                 'quantity': 666,
#                 'stock_code': '22979',
#                 'unit_price': 1.7},
#                {'description': 'PANTRY ROLLING PIN',
#                 'quantity': 708,
#                 'stock_code': '22978',
#                 'unit_price': 4.18},
#                {'description': 'HOMEMADE JAM SCENTED CANDLES',
#                 'quantity': 1428,
#                 'stock_code': '22969',
#                 'unit_price': 1.7},
#                {'description': 'SET OF 6 SPICE TINS PANTRY DESIGN',
#                 'quantity': 852,
#                 'stock_code': '22722',
#                 'unit_price': 4.25},
#                {'description': 'SET OF 3 CAKE TINS PANTRY DESIGN',
#                 'quantity': 612,
#                 'stock_code': '22720',
#                 'unit_price': 5.18},
#                {'description': 'SET OF TEA COFFEE SUGAR TINS PANTRY',
#                 'quantity': 1412,
#                 'stock_code': '23243',
#                 'unit_price': 5.06}]}
# {'_id': 572209,
#  'country': 'United Kingdom',
#  'customer_id': 18102,
#  'date': datetime.datetime(2011, 10, 21, 12, 8),
#  'mean_order_quantity': 274.2857142857143,
#  'mean_order_unit_price': 12.357142857142858,
#  'order_quantity': 1920,
#  'order_total': 22206.0,
#  'purchases': [{'description': 'LANDMARK FRAME COVENT GARDEN',
#                 'quantity': 300,
#                 'stock_code': '23556',
#                 'unit_price': 10.95},
#                {'description': 'LANDMARK FRAME NOTTING HILL',
#                 'quantity': 300,
#                 'stock_code': '23555',
#                 'unit_price': 10.95},
#                {'description': 'LANDMARK FRAME OXFORD STREET',
#                 'quantity': 300,
#                 'stock_code': '23554',
#                 'unit_price': 10.95},
#                {'description': 'LANDMARK FRAME LONDON BRIDGE',
#                 'quantity': 300,
#                 'stock_code': '23558',
#                 'unit_price': 10.95},
#                {'description': 'BOTANICAL GARDENS WALL CLOCK',
#                 'quantity': 120,
#                 'stock_code': '23485',
#                 'unit_price': 20.8},
#                {'description': 'LANDMARK FRAME CAMDEN TOWN',
#                 'quantity': 300,
#                 'stock_code': '23553',
#                 'unit_price': 10.95},
#                {'description': 'LANDMARK FRAME BAKER STREET',
#                 'quantity': 300,
#                 'stock_code': '23557',
#                 'unit_price': 10.95}]}
